# %% [markdown]
# # Projectile Motion
# ## Horizontal Range
# ### - $R = \frac{u^2 sin2\theta}{g}$
# ## Time of Flight
# ### - $T = \frac{2u sin\theta}{g}$
# ## Maximum Height
# ### - $H = \frac{u^2 sin^2\theta}{2g}$

# %% [markdown]
# ### Task:1  Make a class to calculate the range, time of flight and horizontal range of the projectile fired from the ground.
# ### Task: 2 Use the list to find the range, time of flight and horizontal range for variying value of angle from 1 degree to 90 degree.
# ### Task:3 Make a plot to show the variation of range, time of flight and horizontan range with angle of projection.
# ### Task: 4 Change the list of [angle], [Range], [Time of flight], and [Horizontal range] into dictionary and finelly into a DataFrame using pandas. Save the file in your PC in csv file.
# ### Task: 5 Open the csv file and make a plot between the angle vs [range, time of flight and horizontal range] using csv file

# %%
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
class Projectile():
    def __init__(self,u,theta,g):
        self.u=u
        self.theta=theta
        self.g=g
    def HorizontalRange(self):
        return (self.u**2)*math.sin(2*self.theta*math.pi/180)/self.g
    def TimeofFlight(self):
        return (self.u*2)*math.sin(self.theta*math.pi/180)/self.g
    def MaximumHeight(self):
        return (self.u*math.sin(self.theta*math.pi/180))**2/(2*self.g)
    def update_theta(self,theta):
        self.theta=theta

# %%
P=Projectile(u=50,theta=0,g=9.8)#initial velocity = 50m/s, g=9.8 m/s^2
R=[]
T=[]
M=[]
A=[]
x=np.arange(0,90+0.1,0.1)
for i in x:
    A.append(i)
    P.update_theta(i)
    r=P.HorizontalRange()
    t=P.TimeofFlight()
    m=P.MaximumHeight()
    R.append(r)
    T.append(t)
    M.append(m)
    
plt.figure(figsize=[11,11])

plt.subplot(2,2,1)
plt.plot(A,R)
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Horizontal Range (metres)')
plt.title('Horizontal Range vs Angle of Projection')

plt.subplot(2,2,2)
plt.plot(A,T,color='r')
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Time of Flight (seconds)')
plt.title('Time of Flight vs Angle of Projection')

plt.subplot(2,2,3)
plt.plot(A,M,color='g')
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Maximum Height (metres)')
plt.title('Maximum Height vs Angle of Projection')

# %%
data={} #empty dictionary
data.update({"Angle":A,"HorizontalRange":R,"TimeofFlight":T,"MaximumHeight":M})

# %%
Df=pd.DataFrame(data)
print(Df)
# Out:
#      Angle  HorizontalRange  MaximumHeight  TimeofFlight
# 0      0.0     0.000000e+00       0.000000      0.000000
# 1      0.1     8.904723e-01       0.000389      0.017809
# 2      0.2     1.780934e+00       0.001554      0.035619
# 3      0.3     2.671373e+00       0.003497      0.053428
# 4      0.4     3.561781e+00       0.006217      0.071237
# 5      0.5     4.452144e+00       0.009713      0.089046
# 6      0.6     5.342454e+00       0.013987      0.106855
# 7      0.7     6.232699e+00       0.019038      0.124663
# 8      0.8     7.122867e+00       0.024865      0.142471
# 9      0.9     8.012949e+00       0.031469      0.160279
# 10     1.0     8.902933e+00       0.038850      0.178086
# 11     1.1     9.792808e+00       0.047008      0.195892
# 12     1.2     1.068256e+01       0.055942      0.213698
# 13     1.3     1.157219e+01       0.065652      0.231503
# 14     1.4     1.246168e+01       0.076139      0.249308
# 15     1.5     1.335101e+01       0.087402      0.267112
# 16     1.6     1.424018e+01       0.099441      0.284915
# 17     1.7     1.512918e+01       0.112256      0.302717
# 18     1.8     1.601799e+01       0.125846      0.320518
# 19     1.9     1.690661e+01       0.140212      0.338318
# 20     2.0     1.779502e+01       0.155354      0.356117
# 21     2.1     1.868321e+01       0.171271      0.373915
# 22     2.2     1.957118e+01       0.187962      0.391712
# 23     2.3     2.045891e+01       0.205429      0.409508
# 24     2.4     2.134639e+01       0.223670      0.427303
# 25     2.5     2.223361e+01       0.242685      0.445096
# 26     2.6     2.312056e+01       0.262475      0.462888
# 27     2.7     2.400722e+01       0.283038      0.480678
# 28     2.8     2.489360e+01       0.304375      0.498467
# 29     2.9     2.577967e+01       0.326485      0.516254
# ..     ...              ...            ...           ...
# 871   87.1     2.577967e+01     127.224535     10.191014
# 872   87.2     2.489360e+01     127.246645     10.191899
# 873   87.3     2.400722e+01     127.267982     10.192754
# 874   87.4     2.312056e+01     127.288546     10.193577
# 875   87.5     2.223361e+01     127.308335     10.194370
# 876   87.6     2.134639e+01     127.327351     10.195131
# 877   87.7     2.045891e+01     127.345592     10.195861
# 878   87.8     1.957118e+01     127.363058     10.196560
# 879   87.9     1.868321e+01     127.379750     10.197229
# 880   88.0     1.779502e+01     127.395666     10.197866
# 881   88.1     1.690661e+01     127.410808     10.198472
# 882   88.2     1.601799e+01     127.425174     10.199047
# 883   88.3     1.512918e+01     127.438765     10.199590
# 884   88.4     1.424018e+01     127.451579     10.200103
# 885   88.5     1.335101e+01     127.463618     10.200585
# 886   88.6     1.246168e+01     127.474881     10.201036
# 887   88.7     1.157219e+01     127.485368     10.201455
# 888   88.8     1.068256e+01     127.495078     10.201844
# 889   88.9     9.792808e+00     127.504013     10.202201
# 890   89.0     8.902933e+00     127.512170     10.202528
# 891   89.1     8.012949e+00     127.519551     10.202823
# 892   89.2     7.122867e+00     127.526155     10.203087
# 893   89.3     6.232699e+00     127.531983     10.203320
# 894   89.4     5.342454e+00     127.537033     10.203522
# 895   89.5     4.452144e+00     127.541307     10.203693
# 896   89.6     3.561781e+00     127.544804     10.203833
# 897   89.7     2.671373e+00     127.547524     10.203942
# 898   89.8     1.780934e+00     127.549466     10.204019
# 899   89.9     8.904723e-01     127.550632     10.204066
# 900   90.0     3.124099e-14     127.551020     10.204082
#
# [901 rows x 4 columns]

# %%
#create .csv(excel) file
Df.to_csv('Projectile.csv')

# %%
#reading .csv file and plotting its column ve column
df1=pd.read_csv('Projectile.csv')
df1.head() #display function
# Out:
#    Unnamed: 0  Angle  HorizontalRange  MaximumHeight  TimeofFlight
# 0           0    0.0         0.000000       0.000000      0.000000
# 1           1    0.1         0.890472       0.000389      0.017809
# 2           2    0.2         1.780934       0.001554      0.035619
# 3           3    0.3         2.671373       0.003497      0.053428
# 4           4    0.4         3.561781       0.006217      0.071237

# %%
plt.figure(figsize=[11,11])

plt.subplot(2,2,1)
plt.plot(df1.Angle,df1.HorizontalRange)
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Horizontal Range (metres)')
plt.title('Horizontal Range vs Angle of Projection')

plt.subplot(2,2,2)
plt.plot(df1.Angle,df1.TimeofFlight,color='r')
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Time of Flight (seconds)')
plt.title('Time of Flight vs Angle of Projection')

plt.subplot(2,2,3)
plt.plot(df1.Angle,df1.MaximumHeight,color='g')
plt.xlabel('Angle of Projection (degrees)')
plt.ylabel('Maximum Height (metres)')
plt.title('Maximum Height vs Angle of Projection')
